# %% [raw]
# Brainstat python tut
#
# week 2

# %%
# we first want to load brainspace sample data 
from brainstat.datasets import fetch_mask, fetch_template_surface
from brainstat.tutorial.utils import fetch_mics_data

# Load imaging data & behavioral markers
thickness, demographics = fetch_mics_data()
pial_left, pial_right = fetch_template_surface("fsaverage5", join=False)
pial_combined = fetch_template_surface("fsaverage5", join=True)
mask = fetch_mask("fsaverage5")
# Out:
# 2022-06-23 19:25:24,111 - brainstat - INFO - Downloading /Users/boris/brainstat_data/mics_data/mics_demographics.csv from https://box.bic.mni.mcgill.ca/s/7bW9JIpvQvSJeuf/download.
# 2022-06-23 19:25:26,776 - brainstat - INFO - Downloading /Users/boris/brainstat_data/mics_data/mics_thickness.h5 from https://box.bic.mni.mcgill.ca/s/kMi6lU91piwdaCf/download.
# Downloading data from https://files.osf.io/v1/resources/mb37e/providers/osfstorage/5d9f83b6f6b03e00101c932f ...
# Downloaded 1097728 of 4504129 bytes (24.4%,    3.1s remaining)
# 2022-06-23 19:25:51,936 - brainstat - INFO - Downloading /Users/boris/brainstat_data/surface_data/fsaverage5_mask.csv from https://box.bic.mni.mcgill.ca/s/jsSDyiDcm9KEQpf/download.
# Downloaded 3801088 of 4504129 bytes (84.4%,    0.4s remaining) ...done. (10 seconds, 0 min)
# Extracting data from /Users/boris/brainstat_data/surface_data/febf4124525ba216b061a4c71348c702/tpl-fsaverage.tar.gz..... done.

# %%
import numpy as np
from brainspace.plotting import plot_hemispheres


def local_plot_hemispheres(values, label_text, color_range, cmap="viridis"):
    # Plot cortical surfaces with values as the data, label_text as
    # the labels, and color_range as the limits of the color bar.
    return plot_hemispheres(
        pial_left,
        pial_right,
        values,
        color_bar=True,
        color_range=color_range,
        label_text=label_text,
        cmap=cmap,
        embed_nb=True,
        size=(1400, 200),
        zoom=1.45,
        nan_color=(0.7, 0.7, 0.7, 1),
        cb__labelTextProperty={"fontSize": 12},
        interactive=False,
    )


local_plot_hemispheres(np.mean(thickness, axis=0), ["Cortical Thickness"], (1.5, 3.5))

# %%
print(demographics)
# Out:
#     SUB_ID  VISIT  AGE_AT_SCAN SEX
# 0   031404      1           27   F
# 1   04a144      1           25   M
# 2   0b78f1      1           33   M
# 3   0d26b9      1           36   F
# 4   1988b8      1           31   M
# ..     ...    ...          ...  ..
# 77  f25714      1           30   F
# 78  f25714      2           33   F
# 79  f615a5      1           26   F
# 80  feac6b      1           26   F
# 81  feac6b      2           29   F
#
# [82 rows x 4 columns]

# %%
from brainstat.stats.terms import FixedEffect

term_age = FixedEffect(demographics.AGE_AT_SCAN)
model = term_age
print(model)
# Out:
#     intercept  AGE_AT_SCAN
# 0           1           27
# 1           1           25
# 2           1           33
# 3           1           36
# 4           1           31
# ..        ...          ...
# 77          1           30
# 78          1           33
# 79          1           26
# 80          1           26
# 81          1           29
#
# [82 rows x 2 columns]

# %%
from brainstat.stats.SLM import SLM

contrast_age = demographics.AGE_AT_SCAN
slm_age = SLM(
    model,
    contrast_age,
    surf="fsaverage5",
    mask=mask,
    correction=["fdr", "rft"],
    cluster_threshold=0.01,
)
slm_age.fit(thickness)
# Out:
# 2022-06-23 19:27:54,545 - brainstat - INFO - Downloading /var/folders/1j/hnn3hqs52jl018dnp7mjl6kw0000gn/T/tmpe94kvj1y.zip from https://box.bic.mni.mcgill.ca/s/vcSXEk1wx0jN86N/download.

# %%
local_plot_hemispheres(slm_age.t, ["t-values"], (-4, 4), "bwr")

# %%
local_plot_hemispheres(-slm_age.t, ["t-values"], (-4, 4), "bwr")

# %%
plot_pvalues = [np.copy(slm_age.P["pval"]["C"])]
[np.place(x, np.logical_or(x > 0.05, ~mask), np.nan) for x in plot_pvalues]
local_plot_hemispheres(plot_pvalues, ["p-values"], (0, 0.05), "plasma_r")

# %%
print(slm_age.P["clus"][1])
# Out:
#     clusid  nverts    resels         P
# 0        1   141.0  6.283315  0.000033
# 1        2    82.0  3.994467  0.001858
# 2        3    69.0  3.871711  0.002362
# 3        4    61.0  3.670485  0.003517
# 4        5    82.0  3.652319  0.003648
# ..     ...     ...       ...       ...
# 73      74     1.0  0.050811  1.000000
# 74      75     1.0  0.043958  1.000000
# 75      76     1.0  0.039022  1.000000
# 76      77     1.0  0.032002  1.000000
# 77      78     1.0  0.019503  1.000000
#
# [78 rows x 4 columns]

# %%
print(slm_age.P["peak"][1])
# Out:
#             t  vertid  clusid          P               yeo7
# 0    5.695420   18720      11   0.001248  Ventral Attention
# 1    5.164823    5430      12   0.009035             Limbic
# 2    4.855500   16911       6   0.027242  Ventral Attention
# 3    4.833974   19629       2   0.029335     Frontoparietal
# 4    4.628306   12603      14   0.059519       Default mode
# ..        ...     ...     ...        ...                ...
# 109  2.403000    2276      62  23.356468  Ventral Attention
# 110  2.394788    2185      74  23.709038       Default mode
# 111  2.389922   14687      76  23.918494       Default mode
# 112  2.382012    6087      64  24.258914       Default mode
# 113  2.375295    3243      72  24.548027       Default mode
#
# [114 rows x 5 columns]
